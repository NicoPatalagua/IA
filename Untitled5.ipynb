# %% [markdown]
# #PARCIAL II 2019-2
# ##Inteligencia Articial
# ###Patalagua Nicolás
# #Punto3

# %% [markdown]
# ##Librerias

# %%
import random
# !pip install pyeasyga
from pyeasyga import pyeasyga
