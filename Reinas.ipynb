# %% [markdown]
# <h1>Algo Genéticos: Problemas de las N Reinas</h1>

# %%
import random
# !pip install pyeasyga
from pyeasyga import pyeasyga
# Out:
# Collecting pyeasyga
#   Downloading https://files.pythonhosted.org/packages/3f/1b/d2834ca8e108806734a59579fe38a9fa1329f2527d622c43894c1c85a233/pyeasyga-0.3.1.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from pyeasyga) (1.12.0)
# Building wheels for collected packages: pyeasyga
#   Building wheel for pyeasyga (setup.py) ... done
#   Created wheel for pyeasyga: filename=pyeasyga-0.3.1-py2.py3-none-any.whl size=6775 sha256=1a526a03e95618ae7c1d6f1c83aac07814a298f6244ede4b122adebec04e1bf7
#   Stored in directory: /root/.cache/pip/wheels/ef/cf/ef/7aff9fcd6c1e59dc276182f29a32e7c197665dd5eb547f30e6
# Successfully built pyeasyga
# Installing collected packages: pyeasyga
# Successfully installed pyeasyga-0.3.1

# %% [markdown]
# <h3>Representación</h3>
# Cada solución va ser representada como un vector de tamaño N. - N en este caos es cada posible columna del tablero y cada valor de dimensión la columna.

# %%
# Inicialice su representacion
# 1. No se pueden repetir números en la representación?, pq?
# 2. Que tengo que hacer si quiero un tablero mas grande?
representacion = [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# Vamos a utilizar la librería pyeasyga que se encarga de los procesos de iteración del algoritmo. Creamos una instancia de la clase.
ga = pyeasyga.GeneticAlgorithm(representacion,
                            population_size=200,
                            generations=100,
                            crossover_probability=0.8,
                            mutation_probability=0.2,
                            elitism=True,
                            maximise_fitness=False)

# %% [markdown]
# <h3>Creacion de funciones</h3>

# %%
#Funcion que crea individuos, para la creacion de la población inicial
def create_individual(data):
    individual = data[:]
    random.shuffle(individual)
    return individual

#Ejemplos de dos inidivudos que siguen nuestra representación
ind1eje = create_individual(representacion)
ind2eje = create_individual(representacion)

print(ind1eje)
print(ind2eje)

#Una vez la creamos la asignamos a nuestra instancia de ga.
ga.create_individual = create_individual
# Out:
# [4, 6, 0, 1, 7, 5, 2, 3]
# [4, 3, 2, 6, 5, 0, 7, 1]

# %% [markdown]
# <h3>Creación de función de crossover</h3>

# %%
# Ahora definimos nuestra función de crossover, no podemos simplemente cruzarlos daña la representación
def crossover(parent_1, parent_2):
    crossover_index = random.randrange(1, len(parent_1))
    #print(crossover_index)
    child_1a = parent_1[:crossover_index]
    child_1b = [i for i in parent_2 if i not in child_1a]
    child_1 = child_1a + child_1b

    child_2a = parent_2[crossover_index:]
    child_2b = [i for i in parent_1 if i not in child_2a]
    child_2 = child_2a + child_2b

    return child_1, child_2

#Ejemplo de operador de crossover
print(crossover(ind1eje,ind2eje))


#Una vez la creamos la asignamos a nuestra instancia ga.
ga.crossover_function = crossover
# Out:
# ([4, 6, 1, 2, 5, 7, 0, 3], [2, 5, 6, 4, 1, 7, 3, 0])

# %% [markdown]
# <h3>Creamos la función de mutación</h3>

# %%
#Definimos la función de mutación
def mutate(individual):
    mutate_index1 = random.randrange(len(individual))
    mutate_index2 = random.randrange(len(individual))
    individual[mutate_index1], individual[mutate_index2] = individual[mutate_index2], individual[mutate_index1]

print(ind1eje)
mutate(ind1eje)
print(ind1eje)

#Una vez la creamos la asignamos a nuestra instancia ga.
ga.mutate_function = mutate
# Out:
# [4, 6, 1, 2, 5, 7, 3, 0]
# [4, 6, 1, 0, 5, 7, 3, 2]

# %%
# Función de selección!!, población es un objeto que contiene los individuos y sus atributos como la función de fitness
def selection(population):
    return random.choice(population)

#Una vez la creamos la asignamos a nuestra instancia ga.
ga.selection_function = selection

# %%
# Función de fitness: probablemente la mas importante
def fitness (individual, data):
    collisions = 0
    for item in individual:
        item_index = individual.index(item)
        for elem in individual:
            elem_index = individual.index(elem)
            if item_index != elem_index:
                if item - (elem_index - item_index) == elem or (elem_index - item_index) + item == elem:
                    collisions += 1
    return collisions

# Ejemplo cuantas colisiones tiene este individuo?
coli = [0, 5, 3, 6, 7, 4, 1, 2]
print_board(coli)#Para imprimir el board deben ejecutar primero la función al final del script
print(fitness(coli,representacion))

#Una vez la creamos la asignamos a nuestra instancia ga.
ga.fitness_function = fitness       # set the GA's fitness function
# Out:
# ------------------------
# |X |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |X |  |  |
# ------------------------
# |  |  |  |X |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |X |  |
# ------------------------
# |  |  |  |  |  |  |  |X |
# ------------------------
# |  |  |  |  |X |  |  |  |
# ------------------------
# |  |X |  |  |  |  |  |  |
# ------------------------
# |  |  |X |  |  |  |  |  |
# ------------------------
# 10

# %% [markdown]
# <h2>Ejecutando unas cuantas Generaciones</h2>

# %%
#Primera generación
ga.create_first_generation()
print(ga.current_generation[0:10])

def datos_generacion():
    fitness_po = [i.fitness for i in ga.current_generation]
    average = sum(fitness_po)/len(fitness_po)
    print("Fitness promedio:{} ".format(average))
    print("Mejor Individuo: {}".format(ga.best_individual()))

datos_generacion()
# Out:
# [(0, [5, 3, 0, 4, 7, 1, 6, 2]), (0, [1, 7, 5, 0, 2, 4, 6, 3]), (2, [4, 7, 0, 3, 5, 2, 1, 6]), (4, [3, 7, 2, 1, 6, 4, 5, 0]), (4, [4, 6, 0, 3, 5, 2, 7, 1]), (4, [3, 1, 7, 5, 2, 4, 6, 0]), (4, [5, 3, 6, 1, 7, 4, 2, 0]), (4, [5, 1, 3, 7, 4, 2, 0, 6]), (4, [4, 1, 6, 5, 7, 2, 0, 3]), (4, [0, 4, 6, 1, 5, 7, 2, 3])]
# Fitness promedio:10.02
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])

# %%
#Ahora generemos las siguientes 10 generaciones
for i in range(1, 10):
    print("Generacion #{}".format(i))
    ga.create_next_generation()
    datos_generacion()
# Out:
# Generacion #1
# Fitness promedio:10.24
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #2
# Fitness promedio:9.61
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #3
# Fitness promedio:10.23
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #4
# Fitness promedio:9.8
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #5
# Fitness promedio:10.14
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #6
# Fitness promedio:9.43
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #7
# Fitness promedio:9.75
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #8
# Fitness promedio:9.71
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])
# Generacion #9
# Fitness promedio:9.55
# Mejor Individuo: (0, [5, 3, 0, 4, 7, 1, 6, 2])

# %%
#Para correr todas las generaciones definidas en la inicialización de ga.
ga.run()
ga.best_individual()
# Out:
# (0, [5, 7, 1, 3, 0, 6, 4, 2])

# %% [markdown]
# <h3>Una función para imprimir el tablero</h3>

# %%
def print_board(board_representation):
    def print_x_in_row(row_length, x_position):
        print('', end = '')
        for _ in range(row_length):
            print('---', end = '')
        print('\n|', end = '')
        for i in range(row_length):
            if i == x_position:
                print('{} |'.format('X'), end = '')
            else:
                print('  |', end = '')
        print('')

    def print_board_bottom(row_length):
        print('', end = '')
        for _ in range(row_length):
            print('---', end = '')

    num_of_rows = len(board_representation)
    row_length = num_of_rows    #rows == columns in a chessboard

    for row in range(num_of_rows):
        print_x_in_row(row_length, board_representation[row])

    print_board_bottom(row_length)
    print('\n', end = '')

#ga.run() 
# print the GA's best solution; a solution is valid only if there are no collisions
#if ga.best_individual()[0] == 0:
#    print(ga.best_individual())
#    print_board(ga.best_individual()[1])
#else:
#    print(None)

# %% [markdown]
# <h3>Trabajo para entregar el proximo Lunes (9 am)<h3/>

# %% [markdown]
# 1. Investigue como usar matplotlib para hacer graficas con Python. Va construir diferentes graficas de la evolución del fitness de la población cambiando los parametros del algoritmo genético.
# Valores por defecto: population_size=200, generations=100, crossover_probability=0.8, mutation_probability=0.2, elitism=True, maximise_fitness=False
# 2. Utilizando los valores por defecto (i) grafique la evolución del average fitness por generación para la población (eje y: average fitness, eje x: # generación), (ii) grafique la evolución del fitness del mejor individuo (eje y: fitness del mejor individuo, eje x: # generación).
# 3. Utilice los valores por defecto, grafique la evolución del fitness promedio de la población utilizando  como tamaño de población (i) 10, (ii) 50, (ii) 100, (iii) 500. Que conclusiones obtiene del análisis de las gráficas.
# 4. Repita el punto 2 pero esta vez sin elitismo. Que conclusiones obtiene del análisis de las gráficas.
# 5. Utilice los valores por defecto, grafique la evolución del fitness promedio de la población utilizando como probabilidad de crossover (i) 0.1, (ii) 0.5, (ii) 0.8, (iii) 1. Que conclusiones obtiene del análisis de las gráficas.
# 6. Utilice los valores por defecto, grafique la evolución del fitness promedio de la población utilizando como probabilidad de mutación (i) 0.2, (ii) 0.5, (ii) 0.8, (iii) 1. Que conclusiones obtiene del análisis de las gráficas.
# 7. Implementarlo para un tamaño n generico.
# 8. Implementar función de selección por ruleta.
